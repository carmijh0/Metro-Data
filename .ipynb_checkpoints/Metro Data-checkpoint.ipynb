# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import psycopg2
import sys
import sqlalchemy as sa

# %%
engine = sa.create_engine('postgresql://postgres:postgres@localhost:5432/nashville')
cnx = engine.raw_connection()
data = pd.read_sql('SELECT * FROM property_standards_violations', cnx)

# %%
data.describe()
# Out:
#         request_no   date_recv     prop_apn         prop_address       city  \
# count        51438       51438        51002                51059      50819
# unique       51406         784        30204                30499         16
# top     16-1149433  2017-07-27  04313042100  335  FOREST PARK RD  NASHVILLE
# freq             7         194           51                   50      35124
#
#         state    zip              prop_owner complaint_source  \
# count   50869  51014                   51438            51344
# unique      1     37                   27875               18
# top        TN  37013  OWNER INFO UNAVAILABLE            PHONE
# freq    50869   6498                    6653            18827
#
#         reported_problem status council_district last_activity_date  \
# count              50730  51438            50901              51073
# unique             22408      3               35                819
# top     PROBLEM REPORTED   DONE               13         2017-10-26
# freq                2010  27860             3091                228
#
#                     last_activity last_activity_code violations_noted  \
# count                       51073              51063            35606
# unique                         82                 68             3261
# top     Violation Inspection - PS             VIORES       HIGH WEEDS
# freq                        17621              17092             6689
#
#                                                mapped_loc
# count                                               51061
# unique                                              32410
# top     335 FOREST PARK RD\nMADISON, TN 37115\n(36.258...
# freq                                                   50

# %%
data.head(5)
# Out:
#    request_no   date_recv     prop_apn         prop_address       city state  \
# 0  17-1156755  2017-05-04  05814005400       121  QUEENS LN  NASHVILLE    TN
# 1  17-1165789  2017-08-24  08116056500     1007  11TH AVE N  NASHVILLE    TN
# 2  17-1157131  2017-05-09  10703001600        715  ERMAC DR  NASHVILLE    TN
# 3  17-1161502  2017-07-06  07116009000   903  BLUE RIDGE DR  NASHVILLE    TN
# 4  17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
#
#      zip                           prop_owner complaint_source  \
# 0  37218                     LUSTER, PATRICIA            EMAIL
# 1  37208      SARGENT, THOMAS JR. & CHRISTINE     OTHER SOURCE
# 2  37214  H.H. HERITAGE INN OF NASHVILLE, LLC            PHONE
# 3  37207                  SIMMONS, MABLINE P.            PHONE
# 4  37204          ROBISON, ALEXANDER B. ET UX            PHONE
#
#                 reported_problem status council_district last_activity_date  \
# 0  HOW TAKEN:  EMAIL\nHigh grass   DONE                1         2017-07-13
# 1              High grass/weeds.   DONE               19         2017-08-24
# 2             High grass & weeds   DONE               15         2017-07-13
# 3     Inoperable vehicle on row.   DONE                5         2017-08-24
# 4           Junk, trash & debris   DONE               25         2017-04-06
#
#                        last_activity last_activity_code  \
# 0          Violation Inspection - PS             VIORES
# 1  Initial Violation Inspection - PS              PSNVF
# 2         Env Court 1st Setting - PS           DMJCFINE
# 3  Initial Violation Inspection - PS              PSNVF
# 4          Violation Inspection - PS             VIORES
#
#                     violations_noted  \
# 0                         HIGH WEEDS
# 1                               None
# 2                         HIGH WEEDS
# 3                               None
# 4  OPEN STORAGE, JUNK, TRASH, DEBRIS
#
#                                           mapped_loc
# 0  121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...
# 1  1007 11TH AVE N\nNASHVILLE, TN 37208\n(36.1702...
# 2  715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...
# 3  903 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...
# 4  3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...

# %%
#frequency of "drop-dow" categories from initial codes data

print(data['violations_noted'].value_counts(dropna=False))
# Out:
# NaN                                                                                                                                                                                                                                                                                                               15832
# HIGH WEEDS                                                                                                                                                                                                                                                                                                         6689
# OPEN STORAGE, JUNK, TRASH, DEBRIS                                                                                                                                                                                                                                                                                  5452
# PARKING ON GRASS                                                                                                                                                                                                                                                                                                   3017
# EXTERIOR PROP AREA � OPEN STORAGE - ALL                                                                                                                                                                                                                                                                            1016
# UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                                                                                            982
# VEHICLE IN THE RIGHT OF WAY                                                                                                                                                                                                                                                                                         820
# PARKING ON GRASS,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                                                                           788
# HIGH WEEDS,OPEN STORAGE, JUNK, TRASH, DEBRIS                                                                                                                                                                                                                                                                        778
# USE NOT PERMITTED                                                                                                                                                                                                                                                                                                   766
# OPEN STORAGE, JUNK, TRASH, DEBRIS,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                                                          642
# EXTERIOR PROP AREA � HIGH WEEDS                                                                                                                                                                                                                                                                                     519
# OPEN STORAGE, JUNK, TRASH, DEBRIS,PARKING ON GRASS,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                                         490
# EXTERIOR PROP AREA � OPEN STORAGE � JTD                                                                                                                                                                                                                                                                             430
# OPEN STORAGE, JUNK, TRASH, DEBRIS,PARKING ON GRASS                                                                                                                                                                                                                                                                  419
# EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERIOR PROP AREA � VEHICLES � PARKING                                                                                                                                                                                                                                     331
# EXTERIOR PROP AREA � OPEN STORAGE - VEH                                                                                                                                                                                                                                                                             316
# STRP Permit Required                                                                                                                                                                                                                                                                                                270
# EXTERIOR PROP AREA � VEH � INOP/UNLC                                                                                                                                                                                                                                                                                249
# SIGNS  � PROHIBITED - WIND                                                                                                                                                                                                                                                                                          243
# ADDRESS ID RESIDENTIAL                                                                                                                                                                                                                                                                                              227
# EXTERIOR PROP AREA � VEH � INOP/UNLC,PARKING ON GRASS                                                                                                                                                                                                                                                               196
# BUILDING PERMIT REQUIRED                                                                                                                                                                                                                                                                                            194
# EXTERIOR PROP AREA � VEHICLES � PARKING                                                                                                                                                                                                                                                                             166
# EXTERIOR REPAIR                                                                                                                                                                                                                                                                                                     128
# EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERIOR PROP AREA � VEH � INOP/UNLC                                                                                                                                                                                                                                        125
# OPEN STORAGE, JUNK, TRASH, DEBRIS,USE NOT PERMITTED                                                                                                                                                                                                                                                                 124
# EXTERIOR PROP AREA � OPEN STORAGE - VEH,PARKING ON GRASS                                                                                                                                                                                                                                                            118
# OPEN STORAGE, JUNK, TRASH, DEBRIS,UNLIC / INOP / ACCUMULATION MTR VEHICLES,USE NOT PERMITTED                                                                                                                                                                                                                        116
# GRAFFITI                                                                                                                                                                                                                                                                                                            116
#                                                                                                                                                                                                                                                                                                                   ...
# CORNICES, EAVES, STAIRS, PORCH COLUMNS,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR REPAIR,OPEN STORAGE, JUNK, TRASH, DEBRIS,PAINT EXTERIOR,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                1
# EXTERIOR PROP AREA � FENCE MATERIAL MAIN,OPEN STORAGE, JUNK, TRASH, DEBRIS,PARKING ON GRASS,UNLIC / INOP / ACCUMULATION MTR VEHICLES,USE NOT PERMITTED                                                                                                                                                                1
# ELECTRICAL SYSTEM CERTIFICATION,FIRE PROTECTION � SMOKE DETECTORS,INTERIOR OF BUILDINGS - SURFACES                                                                                                                                                                                                                    1
# CHICKENS AND OTHER DOMESTIC FARM ANIMALS,KEEPING CHICKENS                                                                                                                                                                                                                                                             1
# Building Permit Required,STRP Permit Required                                                                                                                                                                                                                                                                         1
# EXTERIOR OF BLDGS � OVERHANG EXTENSIONS,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,OPEN STORAGE, JUNK, TRASH, DEBRIS                                                                                                                                                                                                       1
# ABANDONED SIGNS,DILAPIDATED SIGNS,EXTERIOR PROP AREA � OPEN STORAGE � JTD,EXTERIOR PROP AREA � OPEN STORAGE - VEH,GRAFFITI,HIGH WEEDS,PROHIBITED SIGNS                                                                                                                                                                1
# Boarding Requirements,BROKEN WINDOW GLASS,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR REPAIR,FAILURE TO SECURE,OPEN STORAGE, JUNK, TRASH, DEBRIS,OVERHAUL PORCH OR STEPS                                                                                                                                           1
# EXTERIOR PROP AREA � OPEN STORAGE � JTD,EXTERIOR PROP AREA � OPEN STORAGE - VEH,HIGH WEEDS,PARKING ON GRASS                                                                                                                                                                                                           1
# INTERIOR OF BLDGS � STRUCTURAL MEMBERS,LEAKING WASHERS ON THE LAVATORY BASIN,PLUMBING SYSTEMS � GENERAL REQUIREMENTS,RAISE AND LEVEL FLOORS,VENTILATION � BATHROOMS AND TOILET ROOMS                                                                                                                                  1
# BOARDING OF VACANT BUILDINGS,BOARDING REQUIREMENTS,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR OF BUILDINGS � DECKS                                                                                                                                                                                                1
# ADEQUATE VENTILATION FOR BATHROOM                                                                                                                                                                                                                                                                                     1
# BROKEN, LOOSE AND MISSING PLASTER,CORRECT OTHER ELECTRICAL DEFECTS,FLOOR COVERING,REPLACE, REPAIR DEFECTIVE EQUIP.                                                                                                                                                                                                    1
# ACCESSORY STRUCTURES,CORNICES, EAVES, STAIRS, PORCH COLUMNS,EXTERIOR REPAIR,OPEN STORAGE, JUNK, TRASH, DEBRIS,PAINT EXTERIOR                                                                                                                                                                                          1
# FENCE HEIGHT � SIDE AND REAR SETBACK,PARKING ON GRASS,USE NOT PERMITTED                                                                                                                                                                                                                                               1
# EXT OF BLDGS � WIND, SKYLIT DOOR FRAMES,EXTERIOR OF BLDGS � CHIMNEYS AND TOWERS,EXTERIOR OF BLDGS � PRO TREATMENT (WOOD),EXTERIOR OF BLDGS � ROOFS � ROOF SYSTEM,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR OF BLDGS � STRUCTURAL MEMBERS,EXTERIOR OF BUILDINGS � EXTERIOR WALLS,EXTERIOR REPAIR � GENERAL        1
# EXTERIOR REPAIR,PROPER MAINTENANCE REQ                                                                                                                                                                                                                                                                                1
# OPEN STORAGE, JUNK, TRASH, DEBRIS,SEWAGE - ILLEGAL WASTE LINE,SEWAGE DISP. IMPROPERLY MAINT.                                                                                                                                                                                                                          1
# PROHIBITED SIGNS,SIGN MATERIAL,SIGNS � PROHIBITED PLACEMENT � PUBLIC                                                                                                                                                                                                                                                  1
# ACCESSORY STRUCTURES,HIGH WEEDS,OPEN STORAGE, JUNK, TRASH, DEBRIS,SWIMMING POOLS,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                             1
# EXTERIOR REPAIR � GENERAL,HIGH WEEDS,OPEN STORAGE, JUNK, TRASH, DEBRIS                                                                                                                                                                                                                                                1
# CLEAN FINISH FOR ALL WALLS CEILINGS DOOR,DAMAGED INTERIOR WALLS, CEILINGS, FLOORS,EXT OF BLDGS � WIND, SKYLIT DOOR FRAMES,EXTERIOR OF BUILDINGS � DOORS,HEATING � HEATING FACILITIES REQUIRED,RODENTS, INFESTATION AND VERMIN,ROOF LEAKING,ROTTED, MISSING OR DEFECTIVE FLOORING,SMOKE DETECTORS                      1
# ACCESSORY STRUCTURES,Boarding Requirements,EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR OF BLDGS � TREATMENT (SIDING),EXTERIOR REPAIR,FAILURE TO SECURE,OPEN STORAGE, JUNK, TRASH, DEBRIS                                                                                                                           1
# OPEN STORAGE, JUNK, TRASH, DEBRIS,PARKING ON GRASS,ROOF LEAKING,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                              1
# CLEAN FINISH FOR ALL WALLS CEILINGS DOOR,DAMAGED INTERIOR WALLS, CEILINGS, FLOORS,ELECTRICAL SYSTEM CERTIFICATION,FIRE PROTECTION � SMOKE DETECTORS,INTERIOR OF BUILDINGS - SURFACES,INTERIOR REPAIR                                                                                                                  1
# CHICKENS AND OTHER DOMESTIC FARM ANIMALS,COMMERCIAL VEHICLE RESIDENTIAL DISTRICT,OPEN STORAGE, JUNK, TRASH, DEBRIS,RV - Campers, Buses Prohibited,UNLIC / INOP / ACCUMULATION MTR VEHICLES,USE NOT PERMITTED                                                                                                          1
# EXTERIOR PROP AREA � SWIMMING POOLS,UNLIC / INOP / ACCUMULATION MTR VEHICLES                                                                                                                                                                                                                                          1
# EXTERIOR OF BLDGS � PRO TREATMENT (WOOD),EXTERIOR OF BLDGS � ROOFS� GUTTER SYS,EXTERIOR OF BUILDINGS � EXTERIOR WALLS,EXTERIOR REPAIR                                                                                                                                                                                 1
# EXTERIOR OF BUILDINGS � PREMISES ID RES,EXTERIOR PROP AREA � FENCE MATERIAL MAIN                                                                                                                                                                                                                                      1
# EXTERIOR OF BLDGS � CHIMNEYS AND TOWERS,EXTERIOR OF BLDGS � PRO TREATMENT (WOOD)                                                                                                                                                                                                                                      1
# Name: violations_noted, Length: 3262, dtype: int64

# %%
#delimeter by "," within the 'violations_noted' column

s1 = data['violations_noted'].str.split(',', expand=True).stack().str.strip().reset_index(level=1, drop=True)

# %%
temp_df = pd.concat([s1], axis=1, keys=['violations_noted'])

# %%
cleaning_standards = (data.drop(['violations_noted'], axis=1).join(temp_df).reset_index(drop=True))

# %%
cleaning_standards.head(15)
# Out:
#     request_no   date_recv     prop_apn         prop_address       city state  \
# 0   17-1156755  2017-05-04  05814005400       121  QUEENS LN  NASHVILLE    TN
# 1   17-1165789  2017-08-24  08116056500     1007  11TH AVE N  NASHVILLE    TN
# 2   17-1157131  2017-05-09  10703001600        715  ERMAC DR  NASHVILLE    TN
# 3   17-1161502  2017-07-06  07116009000   903  BLUE RIDGE DR  NASHVILLE    TN
# 4   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 5   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 6   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 7   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 8   17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 9   17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 10  17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 11  17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 12  17-1165799  2017-08-24  10409011200   3723  RICHLAND AVE  NASHVILLE    TN
# 13  17-1154514  2017-03-20  11613007600        5971  POST RD  NASHVILLE    TN
# 14  17-1154514  2017-03-20  11613007600        5971  POST RD  NASHVILLE    TN
#
#       zip                                        prop_owner complaint_source  \
# 0   37218                                  LUSTER, PATRICIA            EMAIL
# 1   37208                   SARGENT, THOMAS JR. & CHRISTINE     OTHER SOURCE
# 2   37214               H.H. HERITAGE INN OF NASHVILLE, LLC            PHONE
# 3   37207                               SIMMONS, MABLINE P.            PHONE
# 4   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 5   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 6   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 7   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 8   37217                           BARRETT, MALCOLM L. JR.            PHONE
# 9   37217                           BARRETT, MALCOLM L. JR.            PHONE
# 10  37217                           BARRETT, MALCOLM L. JR.            PHONE
# 11  37217                           BARRETT, MALCOLM L. JR.            PHONE
# 12  37205                       DUNDON, THOMAS H. & LEAH A.     Codes Online
# 13  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE            PHONE
# 14  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE            PHONE
#
#                                  reported_problem status council_district  \
# 0                   HOW TAKEN:  EMAIL\nHigh grass   DONE                1
# 1                               High grass/weeds.   DONE               19
# 2                              High grass & weeds   DONE               15
# 3                      Inoperable vehicle on row.   DONE                5
# 4                            Junk, trash & debris   DONE               25
# 5                            Junk, trash & debris   DONE               25
# 6                            Junk, trash & debris   DONE               25
# 7                            Junk, trash & debris   DONE               25
# 8                        Couch in the front ditch   DONE               13
# 9                        Couch in the front ditch   DONE               13
# 10                       Couch in the front ditch   DONE               13
# 11                       Couch in the front ditch   DONE               13
# 12  advertising more guest than allowed on permit   OPEN               24
# 13          mattresses and trash on side of road.   DONE               23
# 14          mattresses and trash on side of road.   DONE               23
#
#    last_activity_date                      last_activity last_activity_code  \
# 0          2017-07-13          Violation Inspection - PS             VIORES
# 1          2017-08-24  Initial Violation Inspection - PS              PSNVF
# 2          2017-07-13         Env Court 1st Setting - PS           DMJCFINE
# 3          2017-08-24  Initial Violation Inspection - PS              PSNVF
# 4          2017-04-06          Violation Inspection - PS             VIORES
# 5          2017-04-06          Violation Inspection - PS             VIORES
# 6          2017-04-06          Violation Inspection - PS             VIORES
# 7          2017-04-06          Violation Inspection - PS             VIORES
# 8          2017-07-13         Env Court 1st Setting - PS           DMJUSTCT
# 9          2017-07-13         Env Court 1st Setting - PS           DMJUSTCT
# 10         2017-07-13         Env Court 1st Setting - PS           DMJUSTCT
# 11         2017-07-13         Env Court 1st Setting - PS           DMJUSTCT
# 12               None                               None               None
# 13         2017-04-06          Violation Inspection - PS             VIORES
# 14         2017-04-06          Violation Inspection - PS             VIORES
#
#                                            mapped_loc violations_noted
# 0   121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...       HIGH WEEDS
# 1   1007 11TH AVE N\nNASHVILLE, TN 37208\n(36.1702...              NaN
# 2   715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...       HIGH WEEDS
# 3   903 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...              NaN
# 4   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...     OPEN STORAGE
# 5   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...             JUNK
# 6   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...            TRASH
# 7   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...           DEBRIS
# 8   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...     OPEN STORAGE
# 9   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...             JUNK
# 10  1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...            TRASH
# 11  1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...           DEBRIS
# 12  3723 RICHLAND AVE\nNASHVILLE, TN 37205\n(36.13...              NaN
# 13  5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...     OPEN STORAGE
# 14  5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...             JUNK

# %%
cleaning_standards.shape
# Out:
# (104320, 17)

# %%
print(cleaning_standards['violations_noted'].value_counts(dropna=False))
# Out:
# NaN                                         15832
# DEBRIS                                      10496
# JUNK                                        10496
# OPEN STORAGE                                10496
# TRASH                                       10496
# HIGH WEEDS                                   8856
# PARKING ON GRASS                             6508
# UNLIC / INOP / ACCUMULATION MTR VEHICLES     4171
# EXTERIOR PROP AREA � OPEN STORAGE - ALL      2686
# USE NOT PERMITTED                            2155
# EXTERIOR PROP AREA � VEH � INOP/UNLC         1068
# EXTERIOR REPAIR                              1026
# EXTERIOR PROP AREA � VEHICLES � PARKING      1008
# EXTERIOR PROP AREA � OPEN STORAGE - VEH       895
# EXTERIOR PROP AREA � HIGH WEEDS               889
# VEHICLE IN THE RIGHT OF WAY                   874
# EXTERIOR PROP AREA � OPEN STORAGE � JTD       807
# ADDRESS ID RESIDENTIAL                        756
# BUILDING PERMIT REQUIRED                      560
# ACCESSORY STRUCTURES                          559
# SIGNS  � PROHIBITED - WIND                    452
# INTERIOR REPAIR                               431
# STRP Permit Required                          394
# PROHIBITED SIGNS                              376
# EXTERIOR OF BLDGS � ROOFS� GUTTER SYS         332
# EXTERIOR OF BLDGS � PRO TREATMENT (WOOD)      309
# COMMERCIAL VEHICLE RESIDENTIAL DISTRICT       272
# LANDLORD REGISTRATION                         259
# EXTERIOR REPAIR � GENERAL                     242
# EXTERIOR PROP AREA � FENCE MATERIAL MAIN      232
#                                             ...
# Water � Supply                                  1
# Electrical Lighting Fixtures                    1
# reproductions depicting acts                    1
# Hours of Collection & Dumpster Required         1
# PROVIDE JUNCTION BOX                            1
# Proper Maintenance Req - Owner                  1
# Unsafe or Illegal Sign                          1
# REPLACE SUBSTANDARD WIRING (DROP-CORDS)         1
# Home Occupation � Conditions                    1
# Old or New Location                             1
# DEFECTIVE WALL OUTLETS ON EXTERIOR              1
# Runoff of contents unlawful                     1
# OUTSIDE WATER FAUCET HANDLE AND FIXTURE         1
# Interiors of Bldgs and Structures Gen           1
# BB beverage in excess of 8 percent              1
# Exterior of Bldgs � Treatment (Siding)          1
# pics                                            1
# OCCUPANCY � SLEEPING ROOMS                      1
# Sanitary Drainage System � General              1
# PRESSURE RELIEF/  WATER HEATER                  1
# CLEAN AMINAL AREAS                              1
# COLD-WATER FAUCET FOR THE LAVATORY              1
# BB purchase unauthorized wholesaler             1
# VERMIN                                          1
# morals                                          1
# Trash Cans                                      1
# VENTILATION � HABITABLE SPACES                  1
# Sales without a permit                          1
# DAMAGED OR LEAKING AERATOR SPRAYER              1
# CONTINUOUS & INTERMITTENT NOISE                 1
# Name: violations_noted, Length: 449, dtype: int64

# %%
types = list(cleaning_standards['violations_noted'])
new = []
for i in types:
    i = str(i).split(' ')
    for j in i:
        if j == '/' or j == '-' or j == chr(65533):
            continue
        j = j.strip(chr(65533))
        new.append(j.lower())
        
new = Counter(new)
print(new.most_common())
# Out:
# [('nan', 15832), ('storage', 15086), ('open', 15024), ('exterior', 11681), ('debris', 10633), ('trash', 10545), ('junk', 10496), ('high', 9780), ('weeds', 9780), ('area', 8299), ('prop', 8285), ('parking', 7730), ('on', 6753), ('grass', 6508), ('vehicles', 5179), ('accumulation', 4172), ('unlic', 4171), ('inop', 4171), ('mtr', 4171), ('of', 3234), ('all', 2834), ('use', 2326), ('permitted', 2186), ('not', 2184), ('veh', 2062), ('repair', 1842), ('required', 1635), ('permit', 1520), ('bldgs', 1273), ('prohibited', 1216), ('in', 1207), ('vehicle', 1183), ('signs', 1146), ('the', 1088), ('inop/unlc', 1071), ('residential', 1045), ('buildings', 1021), ('id', 950), ('right', 874), ('way', 874), ('building', 855), ('interior', 843), ('address', 817), ('jtd', 808), ('structures', 781), ('and', 766), ('system', 632), ('accessory', 559), ('sign', 507), ('roofs', 499), ('', 493), ('wind', 486), ('walls', 483), ('general', 473), ('commercial', 457), ('fence', 429), ('treatment', 417), ('strp', 394), ('overcrowding', 391), ('sys', 366), ('requirements', 358), ('to', 355), ('electrical', 346), ('gutter', 337), ('boarding', 325), ('occupancy', 321), ('material', 316), ('failure', 312), ('pro', 311), ('(wood)', 311), ('ceilings', 310), ('excess', 298), ('landlord', 289), ('registration', 289), ('district', 272), ('plumbing', 270), ('main', 248), ('graffiti', 244), ('defective', 229), ('display', 227), ('front', 225), ('electronic', 224), ('(led)', 224), ('damaged', 219), ('systems', 205), ('drainage', 196), ('fire', 195), ('smoke', 195), ('banners', 190), ('boat', 187), ('yard', 187), ('floors', 185), ('for', 183), ('swimming', 179), ('pools', 179), ('door', 175), ('protection', 173), ('roof', 172), ('doors', 170), ('sanitary', 167), ('water', 167), ('unrelated', 167), ('adults', 167), ('missing', 165), ('secure', 163), ('garbage', 160), ('detectors', 148), ('height', 145), ('clean', 144), ('surfaces', 144), ('obtain', 142), ('finish', 140), ('rubbish', 139), ('stor', 137), ('vacant', 137), ('hazards', 136), ('res', 136), ('premises', 135), ('zoning', 134), ('maintenance', 134), ('truck', 132), ('acces', 126), ('row', 125), ('motion', 123), ('windows', 123), ('property', 122), ('paint', 116), ('heating', 114), ('litter', 107), ('private', 102), ('bedrooms', 101), ('timing', 101), ('(siding)', 99), ('dis/repair', 96), ('other', 95), ('work', 93), ('or', 91), ('stop', 91), ('order', 91), ('posted', 91), ('interiors', 89), ('gen', 89), ('certification', 83), ('fences', 82), ('garage', 79), ('lighting', 77), ('facilities', 76), ('owner', 76), ('decks', 76), ('porch', 76), ('portable', 76), ('downspouts', 74), ('fencing', 74), ('materials', 74), ('handrails', 72), ('dilapidated', 71), ('replace', 71), ('overhaul', 70), ('guards', 69), ('rusted', 68), ('gutters', 68), ('broken', 66), ('setback', 65), ('extermination', 62), ('hvac', 61), ('mechanical', 61), ('equip', 61), ('appliances', 61), ('maint', 60), ('right-of-way', 60), ('trailers', 59), ('watercraft', 59), ('leaking', 59), ('sidewalk', 59), ('driveway', 59), ('openable', 59), ('window', 58), ('drain', 58), ('stairs', 57), ('disposal', 57), ('sales', 56), ('glass', 55), ('tractor-trailer', 55), ('floor', 54), ('off', 54), ('siding', 51), ('rotted', 50), ('sheds', 50), ('garages', 50), ('install', 49), ('defects', 49), ('fixtures', 47), ('detector', 47), ('porches', 47), ('sewage', 46), ('cans', 45), ('flooring', 45), ('cornices', 45), ('eaves', 45), ('columns', 45), ('occupied', 44), ('violation', 44), ('glazing', 43), ('supply', 43), ('wall', 40), ('certificate', 39), ('receptacles', 39), ('closet', 39), ('inside', 38), ('chickens', 38), ('unstop', 38), ('home', 37), ('compliance', 37), ('req', 37), ('(opaque)', 37), ('remove', 36), ('ground', 36), ('illegal', 35), ('stairways', 35), ('temporary', 35), ('covering', 34), ('heater', 34), ('on-premises', 34), ('kitchen', 33), ('sink', 33), ('equipment', 33), ('domestic', 33), ('farm', 33), ('animals', 33), ('occupation', 32), ('(vehicle', 32) ...

# %%
codes = pd.read_excel('Codes List of Violations orig.xlsx', usecols=[0,1,2,3,5])

# %%
codes.head(5)
# Out:
#   VIOLATION_ID ORG_ID VIOLATION_TYPE                  VIOLATION_DESC  \
# 0            1      1        BANNERS                         Banners
# 1            2      1     BGMATOWNER  Proper Maintenance Req - Owner
# 2            4      1      BLDGMAINT          Proper Maintenance Req
# 3            5      1     BLDGPERMIT        Building Permit Required
# 4            6      1      BLDGSCOPE          Scope of Building Code
#
#       REMEDIAL_TEXT
# 0      CAAZ_BANNERS
# 1  CAAH_BG_MATOWNER
# 2   CAAH_BLDG_MAINT
# 3  CAAB_BLDG_PERMIT
# 4   CAAH_BLDG_SCOPE

# %%
codes.describe()
# Out:
#        VIOLATION_ID  ORG_ID VIOLATION_TYPE VIOLATION_DESC  REMEDIAL_TEXT
# count           928     789            788            925            345
# unique          810       2            788            773            210
# top               -       1     BT5755032G              N              2
# freq            119     788              1            137            127

# %%
categories = []
for index, row in codes.iterrows():
    i = row['VIOLATION_ID']
    r = row['REMEDIAL_TEXT']
    v = row['VIOLATION_TYPE']
    
    #We need to make sure that we're only iterating through observations that are integers in the 'Violations_ID.'
    try:
        int(i)
    except:
        continue
    
    if str(r) == 'nan' or str(r) != str(r).upper():
        try:
            categories.append(v[:4])
        except:
            print(v) #error message when finding '917' in the VIOLATION_TYPE column
        continue
    else:
        categories.append(r[:4])

cats = {}
categories = list(set(categories))
for item in categories:
    if item[:3] == 'CAA':
        cats[item] = item
    elif item[:2] == 'BB':
        cats['BB'] = item
    elif item[:2] == 'HD':
        cats['HD'] = item
    elif item[:2] == 'SW':
        cats['SW'] = item
    else:
        cats[item[:3]] = item

print(len(cats.keys()))

#there are 22 separate, unique categories between the the REMEDIAL_TEXT and VIOLATION_TYPE columns, noted as keys within the dictionary.
# Out:
# 917
# 22

# %%
#Converting everything to strings so we can interarte over both columns.  

codes.VIOLATION_TYPE = codes.VIOLATION_TYPE.astype(str)
codes.REMEDIAL_TEXT = codes.REMEDIAL_TEXT.astype(str)

# %%
categories = []

def set_category(dictionary, check, dataframe, index):
    for m, n in dictionary.items():
        for item in n:
            if item in check: #item is "m & n" (corresponding to v and r)
                dataframe.loc[index,'CATEGORY'] = m #new column
        

                

def categorize(df, *args):
    test_scenario = len(args) == 1
    if test_scenario:
        l = args[0] #empty list
    for index, row in df.iterrows():
        i = row['VIOLATION_ID']
        v = row['VIOLATION_TYPE']
        r = row['REMEDIAL_TEXT']
        try:
            int(i) #iterating through all rows with an int under the VIOLATION_ID.
        except:
            continue
    
        if str(r) == 'nan' or str(r) != str(r).upper(): #
            if test_scenario:
                l.append(v[:4]) #adding the four letter string to our list
                
                continue
            else:
                set_category(cats, v, df, index) #assing new column 
                
        else:
            if test_scenario:
                l.append(r[:4]) #ading the four letter string to our list

                continue
            else:
                set_category(cats, r, df, index) #assigning new column
                
              
    if test_scenario:
        return l
    else:
        return df

categories = categorize(codes, categories)

categories = list(set(categories))
cats = {}

for cat in categories: #dictionary to create keys for our categories
    if cat[:3] == 'CAA':
        cats[cat] = []
    elif cat[:2] == 'CA':
        cats[cat[:3]] = []
    elif cat[:3] == 'DUM':
        cats[cat[:3]] = []
    elif cat[0] == '9':
        cats[cat] = []
    else:
        cats[cat[:2]] = []

for i in categories: #looping through the keys to assign matches as values
    for j in cats.keys():
        if j in i:
            cats[j].append(i)
            break

print(cats)
print(len(cats.keys()))
c = []
for v in cats.values():
    for k in v:
        c.append(k)
print(len(c))

new_codes = categorize(codes)
new_codes.to_csv('checker.csv')
# Out:
# {'CAG': ['CAGR', 'CAGQ', 'CAGH', 'CAGK', 'CAGO', 'CAGV', 'CAGP', 'CAGD', 'CAGJ', 'CAGA', 'CAGU', 'CAGL', 'CAGI', 'CAGZ', 'CAGE', 'CAGG', 'CAGM', 'CAGF', 'CAGT', 'CAGB', 'CAGC', 'CAGX'], 'BB': ['BB70', 'BBR9', 'BB07', 'BBR6', 'BBR3', 'BBR8', 'BB72', 'BBR2', 'BBR4', 'BBR1'], 'CAP': ['CAP4', 'CAP1', 'CAP5', 'CAP2', 'CAP0', 'CAP3'], 'CAAA': ['CAAA'], 'CAZ': ['CAZZ'], 'CAAH': ['CAAH'], 'HD': ['HDPM', 'HDVI', 'HD15', 'HD16', 'HD10'], 'CAAM': ['CAAM'], 'CAM': ['CAMC'], 'CAS': ['CAST'], 'CAE': ['CAE2', 'CAE1', 'CAE0'], 'CAL': ['CALL'], 'CAAR': ['CAAR'], 'SW': ['SWVI', 'SWEN'], 'BT': ['BT57', 'BT54'], 'DUM': ['DUMP'], 'CAAZ': ['CAAZ'], 'CAAE': ['CAAE'], 'CAAB': ['CAAB'], '917': ['917'], 'CAH': ['CAHC'], 'CAAF': ['CAAF'], 'CAAP': ['CAAP']}
# 23
# 66

# %%
new_codes.head(5)
# Out:
#   VIOLATION_ID ORG_ID VIOLATION_TYPE                  VIOLATION_DESC  \
# 0            1      1        BANNERS                         Banners
# 1            2      1     BGMATOWNER  Proper Maintenance Req - Owner
# 2            4      1      BLDGMAINT          Proper Maintenance Req
# 3            5      1     BLDGPERMIT        Building Permit Required
# 4            6      1      BLDGSCOPE          Scope of Building Code
#
#       REMEDIAL_TEXT CATEGORY
# 0      CAAZ_BANNERS     CAAZ
# 1  CAAH_BG_MATOWNER     CAAH
# 2   CAAH_BLDG_MAINT     CAAH
# 3  CAAB_BLDG_PERMIT     CAAB
# 4   CAAH_BLDG_SCOPE     CAAH

# %%
#delimeter by "," within the 'VIOLATIONS_DESC' column

s1 = codes['VIOLATION_DESC'].str.split(',', expand=True).stack().str.strip().reset_index(level=1, drop=True)
t = pd.concat([s1], axis=1, keys=['VIOLATION_DESC'])
new_codes = codes.drop(['VIOLATION_DESC'], axis=1).join(t).reset_index(drop=True)

# %%
new_codes
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# 12                                                  14                 1
# 13                                                  15                 1
# 14                                                  16                 1
# 15   (B). It is unlawful for any person to dispose ...  CAMCL_DUMP_DESIG
# 16                                                  17                 1
# 17                                                  18                 1
# 18                                                  19                 1
# 19                                                  20                 1
# 20                                                  21                 1
# 21                                                  22                 1
# 22                                                  23                 1
# 23                                                  24                 1
# 24                                                  25                 1
# 25                                                  26                 1
# 26                                                  27                 1
# 27                                                  28                 1
# 28                                                  29                 1
# 29                                                  30                 1
# ..                                                 ...               ...
# 953                                                949                 1
# 954  Premeditated murder, all sex related crimes, s...               NaN
# 955                                                950                 1
# 956                                                951                 1
# 957  Failure to provide documents verifying Fire Ma...               NaN
# 958                                                952                 1
# 959                                                953                 1
# 960                                                954                 1
# 961                                                955                 1
# 962  All applications for beer permits must be file...               NaN
# 963  This amended rule supersedes and replaces the ...               NaN
# 964                                                956                 1
# 965                                                957                 1
# 966  However, in the event of a complete change in ...               NaN
# 967                                                959                 1
# 968  Any business grandfathered under either of the...               NaN
# 969  2. The distance requirements do not apply to a...               NaN
# 970                                                960                 1
# 971                                                961                 1
# 972                                                962                 1
# 973  These provisions shall apply unless the permit...               NaN
# 974                                                963                 1
# 975                                                964                 1
# 976                                                965                 1
# 977                                                966                 1
# 978                                                967                 1
# 979                                                968                 1
# 980  A grant and delay will be valid for 90 days.  ...               NaN
# 981                                                969                 1
# 982                                                970                 1
#
#     VIOLATION_TYPE         REMEDIAL_TEXT CATEGORY  \
# 0          BANNERS          CAAZ_BANNERS     CAAZ
# 1       BGMATOWNER      CAAH_BG_MATOWNER     CAAH
# 2        BLDGMAINT       CAAH_BLDG_MAINT     CAAH
# 3       BLDGPERMIT      CAAB_BLDG_PERMIT     CAAB
# 4        BLDGSCOPE       CAAH_BLDG_SCOPE     CAAH
# 5       BOARDINGRQ    CAAH_BOARDING_REQU     CAAH
# 6         BOARDVAC  CAAH_BOARDING_VABLDG     CAAH
# 7           CARROW       CAMCL_SEW_CONCT      CAM
# 8         CERTCOMP        CAAZ_CERT_COMP     CAAZ
# 9          CERTOCC         CAAH_CERT_OCC     CAAH
# 10       CHICKFARM    CAAZ_CHICK_ANIMALS     CAAZ
# 11      CONSIGSALE     CAAZ_CONSIGN_SALE     CAAZ
# 12       CROWDEDFM      CAAZ_OVCROWDEDFM     CAAZ
# 13         CROWDGH      CAAZ_OVCROWDEDGH     CAAZ
# 14       DUMPDESIG                   nan      DUM
# 15             nan                     1      NaN
# 16        DUMPSTER      CAMCL_LIT_NOTICE      CAM
# 17         ECSYSHZ      CAAE_ELECSYS_HAZ     CAAE
# 18      ECSYSHZCRT  CAAE_ELECSYS_HAZCERT     CAAE
# 19       ELECEAREC     CAAE_ELECEA_RECPT     CAAE
# 20          ELECEQ          CAAE_ELEC_EQ     CAAE
# 21      ELECEQLIGH     CAAE_ELECEQ_LIGHT     CAAE
# 22         ELECFAC          CAAE_ELECFAC     CAAE
# 23      ELECSVCPAN    CAAE_ELECSVC_PANEL     CAAE
# 24          EXPARK         CAAH_EXT_PARK     CAAH
# 25          EXTACC          CAAH_EXT_ACC     CAAH
# 26        EXTBAHAT        CAAH_EXT_BAHAT     CAAH
# 27          EXTBAL        CAAH_EXT_BALCO     CAAH
# 28       EXTCHIMTW       CAAH_EXT_CHIMTW     CAAH
# 29          EXTDEC         CAAH_EXT_DECK     CAAH
# ..             ...                   ...      ...
# 953          BBR17                   nan       BB
# 954            nan                 10635      NaN
# 955          BBR18                   nan       BB
# 956          BBR19                   nan       BB
# 957            nan                 10635      NaN
# 958          BBR21                   nan       BB
# 959          BBR22                   nan       BB
# 960          BBR24                   nan       BB
# 961          BBR26                   nan       BB
# 962            nan                   nan      NaN
# 963            nan                 10635      NaN
# 964          BBR28                   nan       BB
# 965          BBR29                   nan       BB
# 966            nan                 10635      NaN
# 967          BBR30                   nan       BB
# 968            nan                   nan      NaN
# 969            nan                 10635      NaN
# 970          BBR31                   nan       BB
# 971          BBR32                   nan       BB
# 972          BBR34                   nan       BB
# 973            nan                 10635      NaN
# 974          BBR33                   nan       BB
# 975          BBR35                   nan       BB
# 976          BBR36                   nan       BB
# 977          BBR37                   nan       BB
# 978          BBR38                   nan       BB
# 979          BBR40                   nan       BB
# 980            nan                 10635      NaN
# 981          BBR41                   nan       BB
# 982          BBR39                   nan       BB
#
#                                VIOLATION_DESC
# 0                                     Banners
# 1              Proper Maintenance Req - Owner
# 2                      Proper Maintenance Req
# 3                    Building Permit Required
# 4                      Scope of Building Code
# 5                       Boarding Requirements
# 6                Boarding of Vacant Buildings
# 7                 Vehicle In The Right-Of-Way
# 8          Certificate of Compliance Required
# 9           Certificate of Occupancy Required
# 10   Chickens and Other Domestic Farm Animals
# 11                           Consignment Sale
# 12            Overcrowding – Unrelated Adults
# 13                  Overcrowding – Group Home
# 14                Dumping in permitted places
# 15                                          N
# 16    Hours of Collection & Dumpster Required
# 17                  Electrical System Hazards
# 18            Electrical System Certification
# 19                     Electrical Receptacles
# 20                       Electrical Equipment
# 21               Electrical Lighting Fixtures
# 22             Electrical Facilities Required
# 23                   Electrical Service Panel
# 24    Exterior Prop Area – Vehicles – Parking
# 25      Exterior Prop Area – Acces Structures
# 26     Exterior of Bldgs – Basement Hatchways
# 27          Exterior of Buildings - Balconies
# 28    Exterior of Bldgs – Chimneys and Towers
# 29              Exterior of Buildings – Decks
# ..                                        ...
# 953                 Crimes of moral turpitude
# 954                                         N
# 955                         Health Department
# 956                              Fire Marshal
# 957                                         N
# 958                         Surrender permits
# 959               Complaints filed in writing
# 960                       Old or New Location
# 961                Applications 10 days prior
# 962                                       NaN
# 963                                         N
# 964       Cannot surrender to avoid penalties
# 965  Cannot temporary permits with complaints
# 966                                         N
# 967                             Grandfathered
# 968                                       NaN
# 969                                         N
# 970                         Expanded premises
# 971                           Caterer Permits
# 972                        Standard penalties
# 973                                         N
# 974                Past violations considered
# 975                    LLC equals corporation
# 976            No motions for reconsideration
# 977                     Special Event Permits
# 978                          Suspension Rules
# 979                Deny permit after 6 months
# 980                                         N
# 981          No permit issued with complaints
# 982               Sports Authority Facilities
#
# [983 rows x 6 columns]

# %%
#comparison of rows of between before and after separating by "," within the "VIOLATION_DESC" column.  

codes.shape
# Out:
# (934, 6)

# %%
#replacing 'NaN' with 'Unknown'

cleaning_standards['violations_noted'] = cleaning_standards['violations_noted'].replace(np.NaN, 'Unknown')

# %%
cleaning_standards.head(5)
# Out:
#    request_no   date_recv     prop_apn         prop_address       city state  \
# 0  17-1156755  2017-05-04  05814005400       121  QUEENS LN  NASHVILLE    TN
# 1  17-1165789  2017-08-24  08116056500     1007  11TH AVE N  NASHVILLE    TN
# 2  17-1157131  2017-05-09  10703001600        715  ERMAC DR  NASHVILLE    TN
# 3  17-1161502  2017-07-06  07116009000   903  BLUE RIDGE DR  NASHVILLE    TN
# 4  17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
#
#      zip                           prop_owner complaint_source  \
# 0  37218                     LUSTER, PATRICIA            EMAIL
# 1  37208      SARGENT, THOMAS JR. & CHRISTINE     OTHER SOURCE
# 2  37214  H.H. HERITAGE INN OF NASHVILLE, LLC            PHONE
# 3  37207                  SIMMONS, MABLINE P.            PHONE
# 4  37204          ROBISON, ALEXANDER B. ET UX            PHONE
#
#                 reported_problem status council_district last_activity_date  \
# 0  HOW TAKEN:  EMAIL\nHigh grass   DONE                1         2017-07-13
# 1              High grass/weeds.   DONE               19         2017-08-24
# 2             High grass & weeds   DONE               15         2017-07-13
# 3     Inoperable vehicle on row.   DONE                5         2017-08-24
# 4           Junk, trash & debris   DONE               25         2017-04-06
#
#                        last_activity last_activity_code  \
# 0          Violation Inspection - PS             VIORES
# 1  Initial Violation Inspection - PS              PSNVF
# 2         Env Court 1st Setting - PS           DMJCFINE
# 3  Initial Violation Inspection - PS              PSNVF
# 4          Violation Inspection - PS             VIORES
#
#                                           mapped_loc violations_noted
# 0  121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...       HIGH WEEDS
# 1  1007 11TH AVE N\nNASHVILLE, TN 37208\n(36.1702...          Unknown
# 2  715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...       HIGH WEEDS
# 3  903 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...          Unknown
# 4  3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...     OPEN STORAGE

# %%
new_category = pd.DataFrame([['Unknown', 'UNK']], columns=['VIOLATION_DESC', 'CATEGORY'])
new_codes = new_codes.append(new_category)

# %%
#adding the category column to dataframe
new_codes
# Out:
#     CATEGORY            ORG_ID         REMEDIAL_TEXT  \
# 0       CAAZ                 1          CAAZ_BANNERS
# 1       CAAH                 1      CAAH_BG_MATOWNER
# 2       CAAH                 1       CAAH_BLDG_MAINT
# 3       CAAB                 1      CAAB_BLDG_PERMIT
# 4       CAAH                 1       CAAH_BLDG_SCOPE
# 5       CAAH                 1    CAAH_BOARDING_REQU
# 6       CAAH                 1  CAAH_BOARDING_VABLDG
# 7        CAM                 1       CAMCL_SEW_CONCT
# 8       CAAZ                 1        CAAZ_CERT_COMP
# 9       CAAH                 1         CAAH_CERT_OCC
# 10      CAAZ                 1    CAAZ_CHICK_ANIMALS
# 11      CAAZ                 1     CAAZ_CONSIGN_SALE
# 12      CAAZ                 1      CAAZ_OVCROWDEDFM
# 13      CAAZ                 1      CAAZ_OVCROWDEDGH
# 14       DUM                 1                   nan
# 15       NaN  CAMCL_DUMP_DESIG                     1
# 16       CAM                 1      CAMCL_LIT_NOTICE
# 17      CAAE                 1      CAAE_ELECSYS_HAZ
# 18      CAAE                 1  CAAE_ELECSYS_HAZCERT
# 19      CAAE                 1     CAAE_ELECEA_RECPT
# 20      CAAE                 1          CAAE_ELEC_EQ
# 21      CAAE                 1     CAAE_ELECEQ_LIGHT
# 22      CAAE                 1          CAAE_ELECFAC
# 23      CAAE                 1    CAAE_ELECSVC_PANEL
# 24      CAAH                 1         CAAH_EXT_PARK
# 25      CAAH                 1          CAAH_EXT_ACC
# 26      CAAH                 1        CAAH_EXT_BAHAT
# 27      CAAH                 1        CAAH_EXT_BALCO
# 28      CAAH                 1       CAAH_EXT_CHIMTW
# 29      CAAH                 1         CAAH_EXT_DECK
# ..       ...               ...                   ...
# 954      NaN               NaN                 10635
# 955       BB                 1                   nan
# 956       BB                 1                   nan
# 957      NaN               NaN                 10635
# 958       BB                 1                   nan
# 959       BB                 1                   nan
# 960       BB                 1                   nan
# 961       BB                 1                   nan
# 962      NaN               NaN                   nan
# 963      NaN               NaN                 10635
# 964       BB                 1                   nan
# 965       BB                 1                   nan
# 966      NaN               NaN                 10635
# 967       BB                 1                   nan
# 968      NaN               NaN                   nan
# 969      NaN               NaN                 10635
# 970       BB                 1                   nan
# 971       BB                 1                   nan
# 972       BB                 1                   nan
# 973      NaN               NaN                 10635
# 974       BB                 1                   nan
# 975       BB                 1                   nan
# 976       BB                 1                   nan
# 977       BB                 1                   nan
# 978       BB                 1                   nan
# 979       BB                 1                   nan
# 980      NaN               NaN                 10635
# 981       BB                 1                   nan
# 982       BB                 1                   nan
# 0        UNK               NaN                   NaN
#
#                                VIOLATION_DESC  \
# 0                                     Banners
# 1              Proper Maintenance Req - Owner
# 2                      Proper Maintenance Req
# 3                    Building Permit Required
# 4                      Scope of Building Code
# 5                       Boarding Requirements
# 6                Boarding of Vacant Buildings
# 7                 Vehicle In The Right-Of-Way
# 8          Certificate of Compliance Required
# 9           Certificate of Occupancy Required
# 10   Chickens and Other Domestic Farm Animals
# 11                           Consignment Sale
# 12            Overcrowding – Unrelated Adults
# 13                  Overcrowding – Group Home
# 14                Dumping in permitted places
# 15                                          N
# 16    Hours of Collection & Dumpster Required
# 17                  Electrical System Hazards
# 18            Electrical System Certification
# 19                     Electrical Receptacles
# 20                       Electrical Equipment
# 21               Electrical Lighting Fixtures
# 22             Electrical Facilities Required
# 23                   Electrical Service Panel
# 24    Exterior Prop Area – Vehicles – Parking
# 25      Exterior Prop Area – Acces Structures
# 26     Exterior of Bldgs – Basement Hatchways
# 27          Exterior of Buildings - Balconies
# 28    Exterior of Bldgs – Chimneys and Towers
# 29              Exterior of Buildings – Decks
# ..                                        ...
# 954                                         N
# 955                         Health Department
# 956                              Fire Marshal
# 957                                         N
# 958                         Surrender permits
# 959               Complaints filed in writing
# 960                       Old or New Location
# 961                Applications 10 days prior
# 962                                       NaN
# 963                                         N
# 964       Cannot surrender to avoid penalties
# 965  Cannot temporary permits with complaints
# 966                                         N
# 967                             Grandfathered
# 968                                       NaN
# 969                                         N
# 970                         Expanded premises
# 971                           Caterer Permits
# 972                        Standard penalties
# 973                                         N
# 974                Past violations considered
# 975                    LLC equals corporation
# 976            No motions for reconsideration
# 977                     Special Event Permits
# 978                          Suspension Rules
# 979                Deny permit after 6 months
# 980                                         N
# 981          No permit issued with complaints
# 982               Sports Authority Facilities
# 0                                     Unknown
#
#                                           VIOLATION_ID VIOLATION_TYPE
# 0                                                    1        BANNERS
# 1                                                    2     BGMATOWNER
# 2                                                    4      BLDGMAINT
# 3                                                    5     BLDGPERMIT
# 4                                                    6      BLDGSCOPE
# 5                                                    7     BOARDINGRQ
# 6                                                    8       BOARDVAC
# 7                                                    9         CARROW
# 8                                                   10       CERTCOMP
# 9                                                   11        CERTOCC
# 10                                                  12      CHICKFARM
# 11                                                  13     CONSIGSALE
# 12                                                  14      CROWDEDFM
# 13                                                  15        CROWDGH
# 14                                                  16      DUMPDESIG
# 15   (B). It is unlawful for any person to dispose ...            nan
# 16                                                  17       DUMPSTER
# 17                                                  18        ECSYSHZ
# 18                                                  19     ECSYSHZCRT
# 19                                                  20      ELECEAREC
# 20                                                  21         ELECEQ
# 21                                                  22     ELECEQLIGH
# 22                                                  23        ELECFAC
# 23                                                  24     ELECSVCPAN
# 24                                                  25         EXPARK
# 25                                                  26         EXTACC
# 26                                                  27       EXTBAHAT
# 27                                                  28         EXTBAL
# 28                                                  29      EXTCHIMTW
# 29                                                  30         EXTDEC
# ..                                                 ...            ...
# 954  Premeditated murder, all sex related crimes, s...            nan
# 955                                                950          BBR18
# 956                                                951          BBR19
# 957  Failure to provide documents verifying Fire Ma...            nan
# 958                                                952          BBR21
# 959                                                953          BBR22
# 960                                                954          BBR24
# 961                                                955          BBR26
# 962  All applications for beer permits must be file...            nan
# 963  This amended rule supersedes and replaces the ...            nan
# 964                                                956          BBR28
# 965                                                957          BBR29
# 966  However, in the event of a complete change in ...            nan
# 967                                                959          BBR30
# 968  Any business grandfathered under either of the...            nan
# 969  2. The distance requirements do not apply to a...            nan
# 970                                                960          BBR31
# 971                                                961          BBR32
# 972                                                962          BBR34
# 973  These provisions shall apply unless the permit...            nan
# 974                                                963          BBR33
# 975                                                964          BBR35
# 976                                                965          BBR36
# 977                                                966          BBR37
# 978                                                967          BBR38
# 979                                                968          BBR40
# 980  A grant and delay will be valid for 90 days.  ...            nan
# 981                                                969          BBR41
# 982                                                970          BBR39
# 0                                                  NaN            NaN
#
# [984 rows x 6 columns]

# %%
merged_1 = pd.merge(left=cleaning_standards, right=new_codes, how='inner', left_on='violations_noted', right_on='VIOLATION_DESC')

# %%
merged_1.head(15)
# Out:
#     request_no   date_recv        prop_apn           prop_address  \
# 0   17-1156755  2017-05-04     05814005400         121  QUEENS LN
# 1   17-1157131  2017-05-09     10703001600          715  ERMAC DR
# 2   17-1155963  2017-04-24     07301023500     3917  MOSS ROSE DR
# 3   17-1156643  2017-05-02  072090Y00200CO       1003D  SPAIN AVE
# 4   16-1141470  2016-06-15     07116043100     907  BLUE RIDGE DR
# 5   17-1160924  2017-06-27     08104019100        1835  3RD AVE N
# 6   17-1161209  2017-06-30     04415027500      1007  ELLISTON ST
# 7   17-1153795  2017-03-03     16216004000  5418  HICKORY PARK DR
# 8   17-1159515  2017-06-07     16208006200        36  TUSCULUM RD
# 9   17-1164425  2017-08-08  164100A04500CO     4216  SANDSTONE DR
# 10  17-1163877  2017-08-02  104114A00100CO    2001  CONVENT PL  1
# 11  16-1141299  2016-06-13     07511021200         699  MERCER DR
# 12  17-1159884  2017-06-12     10800013100    3071  ELM HILL PIKE
# 13  17-1160533  2017-06-21     10401005900     306  CHAMBERLIN ST
# 14  17-1164009  2017-08-03     08103029400        2019  9TH AVE N
#
#            city state    zip                                prop_owner  \
# 0     NASHVILLE    TN  37218                          LUSTER, PATRICIA
# 1     NASHVILLE    TN  37214       H.H. HERITAGE INN OF NASHVILLE, LLC
# 2     NASHVILLE    TN  37216                    TURNER, TED E. TRUSTEE
# 3     NASHVILLE    TN  37216                           STONE PEAK, LLC
# 4     NASHVILLE    TN  37207                              COOK, MARVIN
# 5     NASHVILLE    TN  37208                     TAB HOMEBUILDERS, LLC
# 6   OLD HICKORY    TN  37138                     ELLISTON STREET TRUST
# 7       ANTIOCH    TN  37013                             RAY, DIANE P.
# 8       ANTIOCH    TN  37013           MEDINA, CELSO & ROSERO, BEATRIZ
# 9       ANTIOCH    TN  37013                    SHARPE, ANGY CULPEPPER
# 10    NASHVILLE    TN  37212            CONVENT PLACE DEVELOPMENT, LLC
# 11    HERMITAGE    TN  37076  RENICK, WILLIAM L., JR. & LACY, NANCY R.
# 12    NASHVILLE    TN  37214                  BROWN, RICKEY LYNN ET UX
# 13    NASHVILLE    TN  37209                        LUNA, ANDY B. ETUX
# 14    NASHVILLE    TN  37208                 FLANIGAN INVESTMENTS, LLC
#
#       complaint_source                                   reported_problem  \
# 0                EMAIL                      HOW TAKEN:  EMAIL\nHigh grass
# 1                PHONE                                 High grass & weeds
# 2                EMAIL                                   high grass/weeds
# 3   INSPECTOR REPORTED                              HIGH GRASS, AND WEEDS
# 4   INSPECTOR REPORTED                                   HIGH GRASS/WEEDS
# 5   INSPECTOR REPORTED  HOW TAKEN:  INSPECTOR REPORTED\nHIGH GRASS AND...
# 6   INSPECTOR REPORTED                                         HIGH GRASS
# 7                EMAIL  HOW TAKEN:  INSPECTOR REPORTED\nOVERGROWTH, JT...
# 8   INSPECTOR REPORTED                                           j/t/d hg
# 9         Codes Online                                   high grass weeds
# 10               EMAIL  HOW TAKEN:  EMAIL\nHIGH GRASS AND WEEDS AND EX...
# 11               PHONE                                         High grass
# 12               PHONE                                         High grass
# 13       Metro Council                               High grass and trash
# 14               PHONE                                   high grass weeds
#
#          ...                      last_activity last_activity_code  \
# 0        ...          Violation Inspection - PS             VIORES
# 1        ...         Env Court 1st Setting - PS           DMJCFINE
# 2        ...          Violation Inspection - PS             VIORES
# 3        ...         PS - Change status to DONE               DONE
# 4        ...          Violation Inspection - PS             VIORES
# 5        ...          Violation Inspection - PS             VIORES
# 6        ...          Violation Inspection - PS             VIORES
# 7        ...         Env Court 1st Setting - PS          INJTNFINE
# 8        ...          Violation Inspection - PS             VIORES
# 9        ...          Violation Inspection - PS             VIORES
# 10       ...          Violation Inspection - PS             VIORES
# 11       ...          Violation Inspection - PS             VIORES
# 12       ...          Violation Inspection - PS             VIORES
# 13       ...          Violation Inspection - PS             VIORES
# 14       ...          Violation Inspection - PS             VIORES
#
#                                            mapped_loc violations_noted  \
# 0   121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...       HIGH WEEDS
# 1   715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...       HIGH WEEDS
# 2   3917 MOSS ROSE DR\nNASHVILLE, TN 37216\n(36.21...       HIGH WEEDS
# 3   1003D SPAIN AVE\nNASHVILLE, TN 37216\n(36.2010...       HIGH WEEDS
# 4   907 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...       HIGH WEEDS
# 5   1835 3RD AVE N\nNASHVILLE, TN 37208\n(36.18704...       HIGH WEEDS
# 6   1007 ELLISTON ST\nOLD HICKORY, TN 37138\n(36.2...       HIGH WEEDS
# 7   5418 HICKORY PARK DR\nANTIOCH, TN 37013\n(36.0...       HIGH WEEDS
# 8   36 TUSCULUM RD\nANTIOCH, TN 37013\n(36.05302, ...       HIGH WEEDS
# 9   4216 SANDSTONE DR\nANTIOCH, TN 37013\n(36.0474...       HIGH WEEDS
# 10  2001 CONVENT PL 1\nNASHVILLE, TN 37212\n(36.13...       HIGH WEEDS
# 11  699 MERCER DR\nHERMITAGE, TN 37076\n(36.198527...       HIGH WEEDS
# 12  3071 ELM HILL PIKE\nNASHVILLE, TN 37214\n(36.1...       HIGH WEEDS
# 13  306 CHAMBERLIN ST\nNASHVILLE, TN 37209\n(36.14...       HIGH WEEDS
# 14  2019 9TH AVE N\nNASHVILLE, TN 37208\n(36.18615...       HIGH WEEDS
#
#    CATEGORY ORG_ID REMEDIAL_TEXT VIOLATION_DESC VIOLATION_ID   VIOLATION_TYPE
# 0      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 1      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 2      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 3      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 4      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 5      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 6      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 7      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 8      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 9      CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 10     CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 11     CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 12     CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 13     CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
# 14     CAAA      1           nan     HIGH WEEDS          392  CAAA_HIGH_WEEDS
#
# [15 rows x 23 columns]

# %%
for c in codes.loc[16,'VIOLATION_DESC']: 
    print (c,ord(c))
# Out:
# H 72
# o 111
# u 117
# r 114
# s 115
#   32
# o 111
# f 102
#   32
# C 67
# o 111
# l 108
# l 108
# e 101
# c 99
# t 116
# i 105
# o 111
# n 110
#   32
# & 38
#   32
# D 68
# u 117
# m 109
# p 112
# s 115
# t 116
# e 101
# r 114
#   32
# R 82
# e 101
# q 113
# u 117
# i 105
# r 114
# e 101
# d 100

# %%
cleaning_standards['violations_noted'] = cleaning_standards['violations_noted'].str.replace(chr(65533), '-')
new_codes['VIOLATION_DESC'] = new_codes['VIOLATION_DESC'].str.replace(chr(226) + chr(128) + chr(147), '-')
new_codes['VIOLATION_DESC'] = new_codes['VIOLATION_DESC'].str.replace(chr(8211), '-')

# %%
cleaning_standards['violations_noted'] = cleaning_standards['violations_noted'].str.lower()
new_codes['VIOLATION_DESC'] = new_codes['VIOLATION_DESC'].str.lower()

# %%
#Making sure I have the correct number of columns and rows in both dataframes before merging. 
cleaning_standards.shape
# Out:
# (104320, 17)

# %%
new_codes.shape
# Out:
# (984, 6)

# %%
merged = pd.merge(left=cleaning_standards, right=new_codes, how='left', left_on='violations_noted', right_on='VIOLATION_DESC')

# %%
merged.head(5)
# Out:
#    request_no   date_recv     prop_apn         prop_address       city state  \
# 0  17-1156755  2017-05-04  05814005400       121  QUEENS LN  NASHVILLE    TN
# 1  17-1165789  2017-08-24  08116056500     1007  11TH AVE N  NASHVILLE    TN
# 2  17-1157131  2017-05-09  10703001600        715  ERMAC DR  NASHVILLE    TN
# 3  17-1161502  2017-07-06  07116009000   903  BLUE RIDGE DR  NASHVILLE    TN
# 4  17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
#
#      zip                           prop_owner complaint_source  \
# 0  37218                     LUSTER, PATRICIA            EMAIL
# 1  37208      SARGENT, THOMAS JR. & CHRISTINE     OTHER SOURCE
# 2  37214  H.H. HERITAGE INN OF NASHVILLE, LLC            PHONE
# 3  37207                  SIMMONS, MABLINE P.            PHONE
# 4  37204          ROBISON, ALEXANDER B. ET UX            PHONE
#
#                 reported_problem        ...          \
# 0  HOW TAKEN:  EMAIL\nHigh grass        ...
# 1              High grass/weeds.        ...
# 2             High grass & weeds        ...
# 3     Inoperable vehicle on row.        ...
# 4           Junk, trash & debris        ...
#
#                        last_activity last_activity_code  \
# 0          Violation Inspection - PS             VIORES
# 1  Initial Violation Inspection - PS              PSNVF
# 2         Env Court 1st Setting - PS           DMJCFINE
# 3  Initial Violation Inspection - PS              PSNVF
# 4          Violation Inspection - PS             VIORES
#
#                                           mapped_loc violations_noted  \
# 0  121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...       high weeds
# 1  1007 11TH AVE N\nNASHVILLE, TN 37208\n(36.1702...          unknown
# 2  715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...       high weeds
# 3  903 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...          unknown
# 4  3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...     open storage
#
#   CATEGORY ORG_ID REMEDIAL_TEXT VIOLATION_DESC VIOLATION_ID     VIOLATION_TYPE
# 0     CAAA      1           nan     high weeds          392    CAAA_HIGH_WEEDS
# 1      UNK    NaN           NaN        unknown          NaN                NaN
# 2     CAAA      1           nan     high weeds          392    CAAA_HIGH_WEEDS
# 3      UNK    NaN           NaN        unknown          NaN                NaN
# 4     CAAA      1           nan   open storage          396  CAAA_OPEN_STORAGE
#
# [5 rows x 23 columns]

# %%
merged.shape
# Out:
# (122357, 23)

# %%
merged.describe()
# Out:
#         request_no   date_recv     prop_apn     prop_address       city  \
# count       122357      122357       121679           121777     121304
# unique       51406         784        30204            30499         16
# top     15-1125042  2017-01-27  04313042100  651  JOSEPH AVE  NASHVILLE
# freq            37         448          147              138      82817
#
#          state     zip              prop_owner complaint_source  \
# count   121387  121704                  122357           122078
# unique       1      37                   27875               18
# top         TN   37013  OWNER INFO UNAVAILABLE            PHONE
# freq    121387   14623                   16500            46418
#
#         reported_problem        ...                      last_activity  \
# count             120775        ...                             121985
# unique             22408        ...                                 82
# top     PROBLEM REPORTED        ...          Violation Inspection - PS
# freq                6562        ...                              48530
#
#        last_activity_code                                         mapped_loc  \
# count              121949                                             121779
# unique                 68                                              32410
# top                VIORES  5319 NOLENSVILLE PIKE\nNASHVILLE, TN 37211\n(3...
# freq                45302                                                132
#
#        violations_noted CATEGORY  ORG_ID REMEDIAL_TEXT VIOLATION_DESC  \
# count            122357   122356  106524        106524         122356
# unique              391       23       1           167            390
# top             unknown     CAAA       1           nan        unknown
# freq              15832    65881  106524         89020          15832
#
#         VIOLATION_ID     VIOLATION_TYPE
# count         106524             106524
# unique           527                527
# top              396  CAAA_OPEN_STORAGE
# freq           41984              41984
#
# [4 rows x 23 columns]

# %%
import re

# after reading the property standards data

# To pull latitude & longitude from the mapped_loc column to two new columns,
# we first need a function to extract lat and lng

# 121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718, -86.861065)
lat_lng_pattern = re.compile(r'\((.*),\s*(.*)\)', flags=re.MULTILINE)


def extract_lat_lng(address):
    try:
        lat_lng_match = lat_lng_pattern.search(address)
        lat = float(lat_lng_match.group(1))
        lng = float(lat_lng_match.group(2))
        return (lat, lng)
    except:
        return (np.NaN, np.NaN)  #it's important that our list be exactly as long as our df
    
    
# Iterating through the mapped_loc column, we apply our function to
# extract lat/lng pairs and store them in a list of tuples.
# Then we can use a list comprehension (or loop) to iterate through the tuple
# and create out two new columns.

lat_lngs = [extract_lat_lng(location) for location in merged.loc[:, 'mapped_loc']]
merged['lat'] = [lat for lat, lng in lat_lngs]
merged['lng'] = [lng for lat, lng in lat_lngs]

# %%
merged.head(15)
# Out:
#     request_no   date_recv     prop_apn         prop_address       city state  \
# 0   17-1156755  2017-05-04  05814005400       121  QUEENS LN  NASHVILLE    TN
# 1   17-1165789  2017-08-24  08116056500     1007  11TH AVE N  NASHVILLE    TN
# 2   17-1157131  2017-05-09  10703001600        715  ERMAC DR  NASHVILLE    TN
# 3   17-1161502  2017-07-06  07116009000   903  BLUE RIDGE DR  NASHVILLE    TN
# 4   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 5   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 6   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 7   17-1153921  2017-03-06  11813018100  3605B  MAYFLOWER PL  NASHVILLE    TN
# 8   17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 9   17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 10  17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 11  17-1156955  2017-05-08  12001009000    1202  VULTEE BLVD  NASHVILLE    TN
# 12  17-1165799  2017-08-24  10409011200   3723  RICHLAND AVE  NASHVILLE    TN
# 13  17-1154514  2017-03-20  11613007600        5971  POST RD  NASHVILLE    TN
# 14  17-1154514  2017-03-20  11613007600        5971  POST RD  NASHVILLE    TN
#
#       zip                                        prop_owner complaint_source  \
# 0   37218                                  LUSTER, PATRICIA            EMAIL
# 1   37208                   SARGENT, THOMAS JR. & CHRISTINE     OTHER SOURCE
# 2   37214               H.H. HERITAGE INN OF NASHVILLE, LLC            PHONE
# 3   37207                               SIMMONS, MABLINE P.            PHONE
# 4   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 5   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 6   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 7   37204                       ROBISON, ALEXANDER B. ET UX            PHONE
# 8   37217                           BARRETT, MALCOLM L. JR.            PHONE
# 9   37217                           BARRETT, MALCOLM L. JR.            PHONE
# 10  37217                           BARRETT, MALCOLM L. JR.            PHONE
# 11  37217                           BARRETT, MALCOLM L. JR.            PHONE
# 12  37205                       DUNDON, THOMAS H. & LEAH A.     Codes Online
# 13  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE            PHONE
# 14  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE            PHONE
#
#                                  reported_problem    ...      \
# 0                   HOW TAKEN:  EMAIL\nHigh grass    ...
# 1                               High grass/weeds.    ...
# 2                              High grass & weeds    ...
# 3                      Inoperable vehicle on row.    ...
# 4                            Junk, trash & debris    ...
# 5                            Junk, trash & debris    ...
# 6                            Junk, trash & debris    ...
# 7                            Junk, trash & debris    ...
# 8                        Couch in the front ditch    ...
# 9                        Couch in the front ditch    ...
# 10                       Couch in the front ditch    ...
# 11                       Couch in the front ditch    ...
# 12  advertising more guest than allowed on permit    ...
# 13          mattresses and trash on side of road.    ...
# 14          mattresses and trash on side of road.    ...
#
#                                            mapped_loc violations_noted  \
# 0   121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...       high weeds
# 1   1007 11TH AVE N\nNASHVILLE, TN 37208\n(36.1702...          unknown
# 2   715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...       high weeds
# 3   903 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...          unknown
# 4   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...     open storage
# 5   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...             junk
# 6   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...            trash
# 7   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...           debris
# 8   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...     open storage
# 9   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...             junk
# 10  1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...            trash
# 11  1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...           debris
# 12  3723 RICHLAND AVE\nNASHVILLE, TN 37205\n(36.13...          unknown
# 13  5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...     open storage
# 14  5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...             junk
#
#    CATEGORY ORG_ID REMEDIAL_TEXT VIOLATION_DESC VIOLATION_ID  \
# 0      CAAA      1           nan     high weeds          392
# 1       UNK    NaN           NaN        unknown          NaN
# 2      CAAA      1           nan     high weeds          392
# 3       UNK    NaN           NaN        unknown          NaN
# 4      CAAA      1           nan   open storage          396
# 5      CAAA      1           nan           junk          396
# 6      CAAA      1           nan          trash          396
# 7      CAAA      1           nan         debris          396
# 8      CAAA      1           nan   open storage          396
# 9      CAAA      1           nan           junk          396
# 10     CAAA      1           nan          trash          396
# 11     CAAA      1           nan         debris          396
# 12      UNK    NaN           NaN        unknown          NaN
# 13     CAAA      1           nan   open storage          396
# 14     CAAA      1           nan           junk          396
#
#        VIOLATION_TYPE        lat        lng
# 0     CAAA_HIGH_WEEDS  36.213718 -86.861065
# 1                 NaN  36.170252 -86.795985
# 2     CAAA_HIGH_WEEDS  36.146283 -86.688968
# 3                 NaN  36.196921 -86.754177
# 4   CAAA_OPEN_STORAGE  36.108083 -86.782690
# 5   CAAA_OPEN_STORAGE  36.108083 -86.782690
# 6   CAAA_OPEN_STORAGE  36.108083 -86.782690
# 7   CAAA_OPEN_STORAGE  36.108083 -86.782690
# 8   CAAA_OPEN_STORAGE  36.123753 -86.703178
# 9   CAAA_OPEN_STORAGE  36.123753 -86.703178
# 10  CAAA_OPEN_STORAGE  36.123753 -86.703178
# 11  CAAA_OPEN_STORAGE  36.123753 -86.703178
# 12                NaN  36.134004 -86.830684
# 13  CAAA_OPEN_STORAGE  36.107168 -86.868488
# 14  CAAA_OPEN_STORAGE  36.107168 -86.868488
#
# [15 rows x 25 columns]

# %%
merged.groupby('CATEGORY').size()
# Out:
# CATEGORY
# 917        21
# BB         19
# BT          2
# CAAA    65881
# CAAB     1503
# CAAE      614
# CAAF      390
# CAAH    23487
# CAAM      122
# CAAP      858
# CAAR       60
# CAAZ    10494
# CAE       174
# CAG       437
# CAH        18
# CAL       259
# CAM        11
# CAP       242
# CAS      1754
# CAZ         1
# DUM        20
# HD        157
# UNK     15832
# dtype: int64

# %%
meaning = {'BB':'Alcohol Board','BT':'Alcohol Board','HD':'Trash or Environmental','SW':'Sewer / Water','CAAA':'Bldg - Exterior','CAAB':'Building & Fire','CAAE':'Electric Board','CAAF':'Building & Fire','CAAH':'Bldg - Construction','CAAM':'Mechanical Board','CAAP':'Plumbing','CAAR':'Bldg Registration','CAAZ':'Zoning Board','CAE':'Electrical','CAG':'Gas','CAH':'Electrical','CAL':'Electrical','CAM':'Building - Moving','CAP':'Plumbing','CAS':'Bldg - Construction','CAZ':'Zoning Board','DUM':'Trash or Environmental', 'UNK':'Unknown'}
merged['meaning'] = merged['CATEGORY'].map(meaning)
print(merged[['CATEGORY', 'meaning']].head(25))
# Out:
#    CATEGORY              meaning
# 0      CAAA      Bldg - Exterior
# 1       UNK              Unknown
# 2      CAAA      Bldg - Exterior
# 3       UNK              Unknown
# 4      CAAA      Bldg - Exterior
# 5      CAAA      Bldg - Exterior
# 6      CAAA      Bldg - Exterior
# 7      CAAA      Bldg - Exterior
# 8      CAAA      Bldg - Exterior
# 9      CAAA      Bldg - Exterior
# 10     CAAA      Bldg - Exterior
# 11     CAAA      Bldg - Exterior
# 12      UNK              Unknown
# 13     CAAA      Bldg - Exterior
# 14     CAAA      Bldg - Exterior
# 15     CAAA      Bldg - Exterior
# 16     CAAA      Bldg - Exterior
# 17     CAAA      Bldg - Exterior
# 18     CAAA      Bldg - Exterior
# 19     CAAH  Bldg - Construction
# 20     CAAH  Bldg - Construction
# 21     CAAZ         Zoning Board
# 22     CAAZ         Zoning Board
# 23     CAAH  Bldg - Construction
# 24     CAAH  Bldg - Construction

# %%
merged['meaning'].value_counts()
# Out:
# Bldg - Exterior           65881
# Bldg - Construction       25241
# Unknown                   15832
# Zoning Board              10495
# Building & Fire            1893
# Plumbing                   1100
# Electric Board              614
# Electrical                  451
# Gas                         437
# Trash or Environmental      177
# Mechanical Board            122
# Bldg Registration            60
# Alcohol Board                21
# Building - Moving            11
# Name: meaning, dtype: int64

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
map_options = GMapOptions(lat=36.16, lng=-86.77, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
)
plot.title.text = "Nashville Codes Violations"
plot.api_key = "AIzaSyBEripH1KKhhzelgtzQAN1Qf3jmzudDQHc"

source = ColumnDataSource(
    data=dict(
        lat=merged['lat'],
        lon=merged['lng'],
    )
)

circle = Circle(x="lon", y="lat", size=3, fill_color="blue", fill_alpha=0.3, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_file("gmap_plot.html")
show(plot)
